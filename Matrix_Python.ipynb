# %% [markdown]
# <a href="https://colab.research.google.com/github/alaanasser12345/DS502/blob/main/Matrix_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # import libraries

# %%
import pandas as pd
import numpy as np
from IPython.display import Image

# %%
Image("Screenshot 2023-03-06 110156.png")

# %%
matrix_1= np.array([[3,4,3],
                   [5,6,0],
                   [2,9,4],
                   [1,1,7]])
matrix_1
# Out:
# array([[3, 4, 3],
#        [5, 6, 0],
#        [2, 9, 4],
#        [1, 1, 7]])

# %%
matrix_1_data_frame = pd.DataFrame(matrix_1, columns=["Type_1","Type_2","Type_3"],index=["Jan","Feb","March","April"])
matrix_1_data_frame
# Out:
#        Type_1  Type_2  Type_3
# Jan         3       4       3
# Feb         5       6       0
# March       2       9       4
# April       1       1       7

# %% [markdown]
# **(a) Express the previous table in matrix form manually
# and using Python**

# %%
matrix_1_data_frame["Type_1"]=matrix_1_data_frame["Type_1"]*1
matrix_1_data_frame["Type_2"]=matrix_1_data_frame["Type_2"]*2
matrix_1_data_frame["Type_3"]=matrix_1_data_frame["Type_3"]*3
matrix_1_data_frame
# Out:
#        Type_1  Type_2  Type_3
# Jan         3       8       9
# Feb         5      12       0
# March       2      18      12
# April       1       2      21

# %%
matrix_2=np.array([[1],
                   [2],
                   [3]])
matrix_2
# Out:
# array([[1],
#        [2],
#        [3]])

# %% [markdown]
# **What information is represented by the following
# product?**

# %%
 product = np.dot(matrix_1_data_frame,matrix_2)
 product
# Out:
# array([[46],
#        [29],
#        [74],
#        [68]])

# %%
Image("Screenshot 2023-03-06 0121071.png")

# %% [markdown]
# **Let M denote the 4 × 3 matrix of May sales and J the 4 × 3 matrix of June sales.**

# %%
Matrix_M= np.array([[45,60,75],
                    [30,30,40],
                    [12,65,45],
                    [15,40,35]])
Matrix_M
# Out:
# array([[45, 60, 75],
#        [30, 30, 40],
#        [12, 65, 45],
#        [15, 40, 35]])

# %%
Matrix_J= np.array([[30,33,40],
                    [21,23,25],
                    [9,12,11],
                    [8,10,9]])
Matrix_J
# Out:
# array([[30, 33, 40],
#        [21, 23, 25],
#        [ 9, 12, 11],
#        [ 8, 10,  9]])

# %% [markdown]
# **(a) What does the matrix M + J represent?**

# %%
Sum= Matrix_M_data_frame+Matrix_J_DataFrame
Sum
# Out:
#            Small  Meduim  Large
# Shirts        75      93    115
# Jeans         51      53     65
# Suits         21      77     56
# RainCoats     23      50     44

# %% [markdown]
# **What does the matrix M − J represent?**

# %%
Sub= Matrix_M_data_frame-Matrix_J_DataFrame
Sub
# Out:
#            Small  Meduim  Large
# Shirts        15      27     35
# Jeans          9       7     15
# Suits          3      53     34
# RainCoats      7      30     26

# %% [markdown]
# **(c) Find a column vector x for which Mx provides a list of the number of shirts, jeans, suits, and raincoats sold in May.**

# %%
Matrix_M_data_frame
# Out:
#            Small  Meduim  Large
# Shirts        45      60     75
# Jeans         30      30     40
# Suits         12      65     45
# RainCoats     15      40     35

# %%
x = np.ones((3,1),dtype="int64")
x
# Out:
# array([[1],
#        [1],
#        [1]])

# %%
xM=np.dot(Matrix_M_data_frame,ones)
xM
# Out:
# array([[180],
#        [100],
#        [122],
#        [ 90]])

# %% [markdown]
# **(d) Find a row vector y for which yM provides a list of the number of small, medium, and large items sold in May.**

# %%
Matrix_M_data_frame
# Out:
#            Small  Meduim  Large
# Shirts        45      60     75
# Jeans         30      30     40
# Suits         12      65     45
# RainCoats     15      40     35

# %%
y= np.ones((1,4),dtype="int64")
y
# Out:
# array([[1, 1, 1, 1]])

# %%
yM= np.dot(y,Matrix_M_data_frame)
yM
# Out:
# array([[102, 195, 195]])

# %% [markdown]
# **(e) Using the matrices
# x and
# y that you found in parts (c)
# and (d), what does
# yMx represent?**

# %%
yMx= np.dot(y,Mx)
yMx
# Out:
# array([[492]])
